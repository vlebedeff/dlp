# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
import tensorflow as tf
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
train_images = train_images.reshape(60000, 28 * 28)
train_images = train_images.astype("float32") / 255

test_images = test_images.reshape(10000, 28 * 28)
test_images = test_images.astype("float32") / 255

# %%
import keras
from keras import layers

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
# Out:
# 2025-12-27 12:23:18.974070: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-12-27 12:23:18.974098: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-12-27 12:23:18.974102: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 14.04 GB
# 2025-12-27 12:23:18.974112: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-27 12:23:18.974119: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.fit(train_images, train_labels, epochs=9, batch_size=180)
# Out:
# Epoch 1/9
# 2025-12-27 12:23:19.196682: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8912 - loss: 0.3846
# Epoch 2/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9159 - loss: 0.3002
# Epoch 3/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9167 - loss: 0.3013
# Epoch 4/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9159 - loss: 0.3058
# Epoch 5/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9155 - loss: 0.3100
# Epoch 6/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9145 - loss: 0.3156
# Epoch 7/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9125 - loss: 0.3272
# Epoch 8/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9099 - loss: 0.3435
# Epoch 9/9
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9101 - loss: 0.3465

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_images)
print(predictions[0])
print(predictions[0].argmax())
print(test_labels[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# [8.6145302e-10 1.2171363e-18 1.0067565e-09 1.9262880e-05 3.8813402e-10
#  1.7066331e-08 2.9859555e-18 9.9997294e-01 5.0597365e-08 7.7018794e-06]
# 7
# 7

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9053 - loss: 0.3915
